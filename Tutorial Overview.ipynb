# %% [markdown]
# # PARALLEL ANALYSIS OF MACROMOLECULAR TRANSITIONS WITH MDANALYSIS AND RADICAL.PILOT
#
# *Names*
#
# The tutorial material is available as iPython notebook on Github:
#
# * link
#
# ## Requirements and Setup:
# TBD
#
# Enclosed a list of dependency for installation on other machines:
#
# * iPython
# * Numpy
# * Pandas
# * Scikit-Learn
# * Matplotlib, Seaborn
# * MDAnalysis
# * RADICAL-Pilot
#
# We recommend to use [Anaconda](http://continuum.io/downloads).
#
#
# ## 1. Background
#
# 1. introduce problem:
#    1. quantitative comparison of transitions: PSA
#    2.  large ensembles and all-pairs: pleasingly parallel with radical.pilot (advantage: existing infrastructure, just run serial jobs)
#
# 2. describe data
#    * MD trajectories
#    * numbers, sizes
#
# 3. describe algorithms – briefly
#    1.  PSA: rmsd fitting and metric calculation (Hausdorff or Fréchet)
#    2.  specifics of the partitioning of the ensemble for radical.pilot
#
# 4. description of frame works
#    * MDAnalysis (brief)
#    * radical.pilot – or more likely you will have done this previously ?
#
# ## 2. Tutorial
#
# ### MDAnalysis
#
# More Details
#
# The basic python script for executing PSA through MDAnalysis is show in the [MDAnalysis Notebook](./01_mda/MDAnalysis.ipynb)
#
# ### RADICAL PIlot
# The Pilot-Abstraction has been used to execute task-based workloads on distributed resources. A Pilot-Job is a placeholder job that is submitting to the resource management system and is used as a container for a dynamically determined set of compute tasks.
#
# The Pilot-Abstraction supports heterogeneous resources, including cloud, HPC, and Hadoop resources.
#
# ![Pilot Abstraction](./figures/interoperable_pilot_job.png)
#
# The following example demonstrates how the Pilot-Abstraction is used to execute the PSA algorithm described.
#
# [Link to Notebook](./02_pilot/Radical_Pilot.ipynb)
